# %% [markdown]
# <a href="https://colab.research.google.com/github/GOVINDFROMINDIA/hacktoberfest2022/blob/main/CVSAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

import cv2
print(cv2.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 4.1.2
